# %% [markdown]
# # Section 3: Terminal Solutions

# %% [markdown]
# pwd - current directory
# ls - list files
# cd .. - up folder
# mkdir - create folder
# touch - create file
# cat - show file
# mv - move/rename
# cp - copy
# rm - delete
# git checkout -b - new branch
