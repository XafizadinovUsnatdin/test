# %% [markdown]
# # Section 2: Python Solutions

# %%
a=[1,2,3]
b=a
b.append(4)
print(a)

# %%
x='HumbleBee'
print(x[::-1])

# %%
def is_prime(n):
    if n<2:
        return False
    for i in range(2,int(n**0.5)+1):
        if n%i==0:
            return False
    return True
