# %% [markdown]
# # Section 4: Pandas Solutions

# %%
import pandas as pd
df = pd.read_csv('train.csv')

# %%
df.head()

# %%
df[df['Sex']=='female']

# %%
df[df['Age']>30]

# %%
df['Age'].mean()

# %%
df['Age'].median()

# %%
df['Embarked'].mode()

# %%
df.groupby('Sex')['Survived'].mean()*100

# %%
df.isnull().sum()
